# %%
# imports
import os
import pandas as pd 
import random

# %%
# variables
startdir = r'C:\Users\achte\Documents\KI_Ba\FileCarver\Dataset\dbc'
outputdir = r'C:\Users\achte\Documents\KI_Ba\FileCarver\Dataset\dbc_new'
file_names = []
keywords = ["VERSION", "NS_", "BO_", "BU_:","BS_:", "CM_", "VAL_"]

# %%
# get all files in path

for path, subdir, files in os.walk(startdir):
    for file in files:
        file_names.append(startdir + "\\" + file)
file_names
# Out:
# ['C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\acura_ilx_2016_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\acura_ilx_2016_nidec.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\acura_rdx_2018_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\acura_rdx_2020_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\bmw_e9x_e8x.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\cadillac_ct6_chassis.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\cadillac_ct6_object.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\cadillac_ct6_powertrain.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\chrysler_pacifica_2017_hybrid_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\chrysler_pacifica_2017_hybrid_private_fusion.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\chrysler_ram_dt_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\chrysler_ram_hd_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\comma_body.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\ESR.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\FORD_CADS.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\ford_cgea1_2_bodycan_2011.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\ford_cgea1_2_ptcan_2011.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\ford_fusion_2018_adas.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\ford_fusion_2018_pt.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\ford_lincoln_base_pt.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\gm_global_a_chassis.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\gm_global_a_high_voltage_management.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\gm_global_a_lowspeed.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\gm_global_a_lowspeed_1818125.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\gm_global_a_object.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\gm_global_a_powertrain_expansion.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\gm_global_a_powertrain_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_accord_2018_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_civic_ex_2022_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_civic_hatchback_ex_2017_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_civic_touring_2016_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_clarity_hybrid_2018_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_crv_executive_2016_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_crv_ex_2017_body_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_crv_ex_2017_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_crv_touring_2016_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_fit_ex_2018_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_fit_hybrid_2018_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_insight_ex_2019_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_odyssey_exl_2018_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\honda_odyssey_extreme_edition_2018_china_can_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\hyundai_2015_ccan.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\hyundai_2015_mcan.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\hyundai_canfd.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\hyundai_i30_2014.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\hyundai_kia_generic.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\hyundai_kia_mando_corner_radar_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\hyundai_kia_mando_front_radar_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\hyundai_santafe_2007.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\luxgen_s5_2015.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\mazda_2017.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\mazda_3_2019.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\mazda_radar.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\mazda_rx8.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\mercedes_benz_e350_2010.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\nissan_leaf_2018_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\nissan_xterra_2011.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\nissan_x_trail_2017_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\opel_omega_2001.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\pyproject.toml',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\subaru_forester_2017_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\subaru_global_2017_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\subaru_global_2020_hybrid_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\subaru_outback_2015_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\subaru_outback_2019_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\tesla_can.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\tesla_powertrain.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\tesla_radar.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_2017_ref_pt.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_adas.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_iQ_2009_can.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_new_mc_pt_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_nodsu_pt_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_prius_2010_pt.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_radar_dsu_tssp.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_tnga_k_pt_generated.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\toyota_tss2_adas.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\volvo_v40_2017_pt.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\volvo_v60_2015_pt.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\vw_golf_mk4.dbc',
#  'C:\\Users\\achte\\Documents\\KI_Ba\\FileCarver\\Dataset\\dbc\\vw_mqb_2010.dbc']

# %%
# load dbc file in dataframe

df = pd.DataFrame()

for file in file_names:
        with open(file, 'r') as f:
            dict_file = {i: [] for i in keywords}
            key_alt = ''
            str_new = ''
            for line in f:
                key =  line.split(' ', 1)[0]
                if key in keywords:
                    if not key_alt:
                        key_alt = key
                    if str_new:
                        dict_file[key_alt].append(str_new)
                        str_new = line
                    else:
                        str_new = str_new + line
                    key_alt = key
                else:
                    str_new = str_new + line
            df_dict = pd.DataFrame([dict_file])
            df = pd.concat([df, df_dict], ignore_index=True)
             
df
# Out:
#                VERSION                                                NS_  \
# 0                   []                                                 []
# 1   [VERSION ""\n\n\n]  [NS_ : \n\tNS_DESC_\n\tCM_\n\tBA_DEF_\n\tBA_\n...
# 2                   []                                                 []
# 3                   []                                                 []
# 4   [VERSION ""\n\n\n]  [NS_ :\n    NS_DESC_\n    CM_\n    BA_DEF_\n  ...
# ..                 ...                                                ...
# 76  [VERSION ""\n\n\n]  [NS_ :\n    NS_DESC_\n    CM_\n    BA_DEF_\n  ...
# 77  [VERSION ""\n\n\n]  [NS_ :\n    NS_DESC_\n    CM_\n    BA_DEF_\n  ...
# 78  [VERSION ""\n\n\n]  [NS_ :\n    NS_DESC_\n    CM_\n    BA_DEF_\n  ...
# 79  [VERSION ""\n\n\n]  [NS_ :\n\tNS_DESC_\n\tCM_\n\tBA_DEF_\n\tBA_\n\...
# 80  [VERSION ""\n\n\n]  [NS_ :\n    NS_DESC_\n    CM_\n    BA_DEF_\n  ...
#
#                                                   BO_  \
# 0   [BO_ 512 GAS_COMMAND: 6 EON\n SG_ GAS_COMMAND ...
# 1   [BO_ 768 VEHICLE_STATE: 8 ADAS\n SG_ SET_ME_XF...
# 2   [BO_ 512 GAS_COMMAND: 6 EON\n SG_ GAS_COMMAND ...
# 3   [BO_ 304 GAS_PEDAL_2: 8 PCM\n SG_ ENGINE_TORQU...
# 4   [BO_ 170 AccPedal: 8 DME\n SG_ KickDownPressed...
# ..                                                ...
# 76  [BO_ 384 TRACK_A_0: 8 XXX\n SG_ COUNTER : 7|8@...
# 77  [BO_ 8 SAS0: 8 SAS\n SG_ SteeringDirection : 4...
# 78  [BO_ 16 SAS0: 8 SAS\n SG_ Counter0 : 3|8@0+ (1...
# 79  [BO_ 1394 ZAS_1: 2 XXX\n SG_ Fehlerspeicherein...
# 80  [BO_ 290 ACC_06: 8 XXX\n SG_ CHECKSUM : 0|8@1+...
#
#                                                  BU_: BS_:  \
# 0                                                  []   []
# 1                     [BU_: ADAS RADAR NEO XXX\n\n\n]   []
# 2                                                  []   []
# 3                                                  []   []
# 4   [BU_: EON XXX RDC SZL VGSG JBBF RFK FLA RAD1 C...   []
# ..                                                ...  ...
# 76                                   [BU_: XXX\n\n\n]   []
# 77  [BU_: XXX BCM CEM CVM DIM ECM FSM PSCM SAS SRS...   []
# 78                [BU_: XXX BCM CEM FSM PSCM SAS\n\n]   []
# 79                                   [BU_: XXX\n\n\n]   []
# 80  [BU_: Airbag_MQB BAP_Tester_MQB BMS_MQB Datenl...   []
#
#                                                   CM_  \
# 0   [CM_ "AUTOGENERATED FILE, DO NOT EDIT";\n\n\n,...
# 1   [CM_ SG_ 1024 RADAR_STATE "need to find out mo...
# 2   [CM_ "AUTOGENERATED FILE, DO NOT EDIT";\n\n\n,...
# 3   [CM_ "AUTOGENERATED FILE, DO NOT EDIT";\n\n\n,...
# 4   [CM_ SG_ 170 ThrottlelPressed "Active when acc...
# ..                                                ...
# 76                                                 []
# 77  [CM_ SG_ 85 BrakePedalActive2 "Active during b...
# 78  [CM_ SG_ 16 RateOfChangeOrTorque "Rate of chan...
# 79  [CM_ SG_ 80 Checksumme_Airbag_1 "Checksum Airb...
# 80  [CM_ SG_ 134 LWI_Lenkradwinkel "Steering angle...
#
#                                                  VAL_
# 0   [VAL_ 513 STATE 5 "FAULT_TIMEOUT" 4 "FAULT_STA...
# 1                                                  []
# 2   [VAL_ 513 STATE 5 "FAULT_TIMEOUT" 4 "FAULT_STA...
# 3   [VAL_ 780 CRUISE_SPEED 255 "no_speed" 252 "sto...
# 4   [VAL_ 408 ShifterPosition 1 "D" 2 "S" 3 "N" 4 ...
# ..                                                ...
# 76                                                 []
# 77                                                 []
# 78                                                 []
# 79  [VAL_ 870 AWV_Text 0 "kein_Text" 1 "FrontAssis...
# 80  [VAL_ 159 EPS_HCA_Status 0 "disabled" 1 "initi...
#
# [81 rows x 7 columns]

# %%
# create new dbc files 
file_name = 'generated_dbc_file_'

for i in range(500):
    # create new file
    name = file_name + str(i)
    path = outputdir + '\\' + name + '.dbc'
    
    with open(path, 'w') as f:
    
        len_df = len(df)-1
    
        items = []
        for name in list(df.columns.values):
            randnum = random.randint(0, len_df)
            # for each column pick random row 
            listee = df[name][randnum]
            # pick a number of random objects in list 
            if listee:
                randnum = random.randint(len(listee)//2, len(listee)-1)
                items = random.choices(listee[1:], k=randnum)
                items.insert(0,listee[0])
            for line in listee:
                f.write(line)
